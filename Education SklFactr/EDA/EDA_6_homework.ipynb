# %% [markdown]
# # Домашнее задание

# %% [markdown]
# Визуализируйте корреляцию между числовыми признаками, использованными для обучения модели и залогируйте изображение в Comet.
#
# В качестве ответа приложите обновленный ноутбук.
#
# *Форма оценки ментором:*
#
# 1) Проведена визуализация корреляции между 7 числовыми признаками, использованными для обучения модели - 5 баллов
#
# 2) Произведено логирование графика в CometMl - 10 баллов

# %%
numeric_data= df.copy()
numeric_data.drop(['AppointmentID', 'PatientId', 'ScheduledDay', 'AppointmentDay', 'No-show', 'Gender', 'Neighbourhood'], axis=1, inplace = True)
numeric_data.head()

experiment_1 = Experiment(
    api_key="yTlxtqQZNRKt6odnbU8HzAQVu",
    project_name="med-appointment",
    workspace="ilyaber",
)
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/ilyaber/med-appointment/7fcf5cf538c848c4912ac0eba720e7f2
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     figures                  : 2
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (867 bytes)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# ...

# %%
numeric_data.hist(figsize=(16,14));
experiment_1.log_figure(figure=plt)
# Out:
# {'web': 'https://www.comet.com/api/image/download?imageId=885d2c93ab6f4fada024f4444c526be8&experimentKey=25db17ae93ca47d38c7d0497c4a228c2',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=885d2c93ab6f4fada024f4444c526be8&experimentKey=25db17ae93ca47d38c7d0497c4a228c2',
#  'imageId': '885d2c93ab6f4fada024f4444c526be8'}

# %%
numeric_data_map=sns.heatmap(data=numeric_data.corr(), annot=True)
numeric_data_map.set_title('Тепловая карта корреляции')
experiment_1.log_figure(figure=plt)
# Out:
# {'web': 'https://www.comet.com/api/image/download?imageId=3b558df688d54eef8fda8cd0135f27f6&experimentKey=25db17ae93ca47d38c7d0497c4a228c2',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=3b558df688d54eef8fda8cd0135f27f6&experimentKey=25db17ae93ca47d38c7d0497c4a228c2',
#  'imageId': '3b558df688d54eef8fda8cd0135f27f6'}

# %%
experiment_1.display()
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://www.comet.com/ilyaber/med-appointment/25db17ae93ca47d38c7d0497c4a228c2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
experiment_1.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/ilyaber/med-appointment/25db17ae93ca47d38c7d0497c4a228c2
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     figures                  : 2
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (867 bytes)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ---------------------------
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The Python SDK has 3600 seconds to finish before aborting...
# ...
